# %% [markdown]
# # Exercício 1 - Cadastro e análise simples de veículos
#
# Uma concessionária deseja registrar alguns veículos disponíveis para venda.
# Crie um programa em Python que crie uma lista de veículos.
#
# Cada veículo deve ser representado por um dicionário contendo:
# - marca
# - modelo
# - preço
# - ano
#
# Exemplo de estrutura esperada:
#
# ```
# veiculo = {
#     "marca": "Toyota",
#     "modelo": "Corolla",
#     "preco": 120000,
#     "ano": 2022
# }
# ```
#
# O programa deve:
#
# - Adicionar pelo *menos 5 veículos* à lista.
# - Exibir todos os veículos cadastrados.
# - Calcular o *preço médio dos veículos*.
# - Mostrar quais *veículos custam acima da média*.
#
# ### Saída esperada (exemplo)
# ```
# Preço médio dos veículos: 85000
# Veículos acima da média:
# Honda Civic - 110000
# Toyota Corolla - 120000
# ```

# %%
veiculo = [
    {"marca": "Fiat", "modelo": "Uno", "preço": 80000, "ano": 2023 },
    {"marca": "Toyota", "modelo": "Astra", "preço": 50000, "ano": 2018},
    {"marca": "Ford", "modelo": "Ka", "preço": 90000, "ano": 2024},
    {"marca": "Honda", "modelo": "Civic", "preço": 120000, "ano": 2025},
    {"marca": "BYD", "modelo": "Dolphin", "preço": 150000, "ano": 2026}
]

print("Carros da concessionaria")
for carro in veiculo:
    print (carro["marca"], carro["modelo"], carro["preço"])

soma_total = 0 

for carro in veiculo:
    soma_total = soma_total + carro["preço"] 

media = soma_total / 5
print("Media dos preços", media)



print("Veiculos acima da media:")
for carro in veiculo:
    if carro["preço"] > media:
        print(carro["modelo"], carro["preço"])
# Out:
# Carros da concessionaria
# Fiat Uno 80000
# Toyota Astra 50000
# Ford Ka 90000
# Honda Civic 120000
# BYD Dolphin 150000
# Media dos preços 98000.0
# Veiculos acima da media:
# Civic 120000
# Dolphin 150000

# %% [markdown]
# # Exercício 2 - Sistema simples de financiamento
#
# Uma concessionária oferece financiamento de veículos.
#
# Crie uma função chamada:
#
# ```
# calcular_financiamento(preco, entrada, parcelas)
# ```
#
# A função deve calcular o valor financiado.
#
# ```
# valor_financiado = preco - entrada
# ```
#
# Considerar uma taxa de juros simples de 1.5% ao mês.
#
# Fórmula simplificada:
# ```
# valor_total = valor_financiado * (1 + taxa * parcelas)
# parcela = valor_total / parcelas
# ```
# A função deve retornar o valor da parcela.
#
#
# ### Crie um programa que:
#
# - Defina o preço de um veículo
# - Pergunte ao usuário: valor de entrada e número de parcelas
# - Use a função para calcular o financiamento
# - Exiba o valor da parcela
# - Impedir parcelas maiores que 72 meses
# - Mostrar uma mensagem caso isso ocorra (Número máximo de parcelas é 72.)
#
# ### Exemplo de saída
#
# ```
# Preço do veículo: 80000
# Entrada: 20000
# Parcelas: 48
# Valor da parcela: 1785.50
# ```

# %%
def calcular_financiamento(preco, entradas, parcelas):
    taxa = 0.015

    valor_financiado = preco - entrada

    valor_total = valor_financiado * (1 + taxa * parcelas)

    valor_parcela = valor_total / parcelas

    return valor_parcela

preco_veiculo = 100000
print(f"Preço do veiculo: {preco_veiculo}")

entrada = float(input("Digite o valor de entrada do veiculo: "))
quantidade_parcela = int(input("Digite quantas parcelas deseja para pagar o veiculo: "))

if quantidade_parcela > 72:
    print("Não e possivel o numero limite e de 72 parcelas.")
else: 
    resultado_parcela = calcular_financiamento(preco_veiculo, entrada, quantidade_parcela)

print(f"Valor da parcela: {resultado_parcela: .2f}")
# Out:
# Preço do veiculo: 100000
# Digite o valor de entrada do veiculo:  40000
# Digite quantas parcelas deseja para pagar o veiculo:  30
# Valor da parcela:  2900.00
